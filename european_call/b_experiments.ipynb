# %% [markdown]
# <a href="https://colab.research.google.com/github/ashish1610dhiman/pinn_option_pricing/blob/main/european_call/b_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.autograd as tgrad
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import pandas as pd
import os
from european_utils import EuropeanOptionData, plot_solution
# %matplotlib inline
from model_types import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
N_EPOCH = 80000
LEARNING_RATE = 1e-5
HIDDEN_LAYER = 4
HIDDEN_WIDTH = 128
N_sample = 8000
EXPERIMENT_NAME = "exp_gated3_correct_2e"
PHYSICS_PENALTY = 52
MODEL_TYPE = EuropeanCall_gated3
BVP1_PENALTY = 8
ERR_SAMPLING = False

experiment_dir = f"./{EXPERIMENT_NAME}"
os.makedirs(experiment_dir, exist_ok=True)

# %%
import logging
from datetime import datetime
logger = logging.getLogger()
current_date = datetime.now().strftime("%Y-%m-%d")
log_file_name = f"{experiment_dir}/{EXPERIMENT_NAME}_log_{current_date}.log"
fhandler = logging.FileHandler(filename=log_file_name, mode='w')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.INFO)

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.set_default_device(DEVICE)
logging.info(f"Running on device={DEVICE}")

# %% [markdown]
# ### Parameters for the experiment

# %%
logging.info(f"N_EPOCH: {N_EPOCH}")
logging.info(f"LEARNING_RATE: {LEARNING_RATE}")
logging.info(f"HIDDEN_LAYER: {HIDDEN_LAYER}")
logging.info(f"HIDDEN_WIDTH: {HIDDEN_WIDTH}")
logging.info(f"N_sample: {N_sample}")
logging.info(f"EXPERIMENT_NAME: {EXPERIMENT_NAME}")
logging.info(f"PHYSICS_PENALTY: {PHYSICS_PENALTY}")
logging.info(f"BVP1_PENALTY: {BVP1_PENALTY}")
logging.info(f"ERR_SAMPLING: {ERR_SAMPLING}")
logging.info(f"Model type: {MODEL_TYPE.__name__}")

# %% [markdown]
# ## Declare parameters for European Call

# %%
K = 40
r = 0.05
sigma = 0.2
T = 1
S_range = [0, 160]
t_range = [0, T]

# %%
euro_call_data = EuropeanOptionData(t_range,S_range,K,r,sigma)

# %%
bvp_x1,bvp_y1,bvp_x2,bvp_y2 = euro_call_data.get_bvp_data(500,1,1)
ivp_x1,ivp_y1 = euro_call_data.get_ivp_data(500,1)
diff_x1,diff_y1 = euro_call_data.get_diff_data(2000)
plt.scatter(bvp_x1[:,0],bvp_x1[:,1], label= "BVP 1", color = "red",marker="o")
plt.scatter(bvp_x2[:,0],bvp_x2[:,1], label= "BVP 2", color = "green",marker="x")
plt.scatter(ivp_x1[:,0],ivp_x1[:,1], label= "IVP", color = "blue")
plt.scatter(diff_x1[:,0],diff_x1[:,1], label= "PDE sample", color = "grey", alpha = 0.3)
plt.xlabel(f"current time (t), $t \in (0,1)$")
plt.ylabel("stock price $S$")
plt.title("Data Sampling for European Call")
plt.legend()

# %% [markdown]
# ### Train Pytorch Model

# %%
model = MODEL_TYPE(2,1,HIDDEN_WIDTH, HIDDEN_LAYER).to(DEVICE)
logging.info(f"Model parameters : {sum(p.numel() for p in model.parameters())/10**3:.2f}K")

# %%
# N_sample = 500
physics_lr = PHYSICS_PENALTY
optimizer = torch.optim.Adam(model.parameters(),lr=LEARNING_RATE)

loss_history={
    "total_loss":[],"loss_ivp_bvp":[],"loss_BS":[],\
    "loss_bvp1":[],"loss_bvp2":[],"loss_ivp":[],
}

# %% [markdown]
# * BVP 1 $S = S_{min}$: 0
#
# * BVP2 ($S = S_{max}$): $S_{max} - K \cdot e^{-rt}$
#
# * IVP (t=T): $max(S-K,0)$ *call this initial but corresponds to expiry*

# %%
def get_sample_rt(l1,l2,l3):
    t = l1+l2+l3
    l1 = max(l1*3/t,0.25)
    l2 = max(l2*3/t,0.25)
    l3 = max(l3*3/t,0.25)
    return (l1,l2,l3)

# %%
r_ivp,r_bvp1,r_bvp2 = 1,1,1
for i in range(N_EPOCH):
    model.train();
    # Get IVP data
    ivp_x_tensor,ivp_y_tensor = euro_call_data.get_ivp_data_tensor(N_sample,r_ivp)
    ivp_x_tensor = ivp_x_tensor.to(DEVICE)
    ivp_y_tensor = ivp_y_tensor.to(DEVICE)
    # ivp_x_tensor = euro_call_data.normalize(ivp_x_tensor)
    ivp_y_pred = model(ivp_x_tensor)
    mse_ivp = nn.MSELoss()(ivp_y_tensor, ivp_y_pred)

    # Get BVP data
    bvp_x1_tensor,bvp_y1_tensor,bvp_x2_tensor,bvp_y2_tensor = euro_call_data.get_bvp_data_tensor(N_sample,r_bvp1,r_bvp2)
    bvp_x1_tensor,bvp_y1_tensor = bvp_x1_tensor.to(DEVICE),bvp_y1_tensor.to(DEVICE)
    bvp_x2_tensor,bvp_y2_tensor = bvp_x2_tensor.to(DEVICE),bvp_y2_tensor.to(DEVICE)
    # bvp_x1_tensor = euro_call_data.normalize(bvp_x1_tensor)
    bvp_y1_pred = model(bvp_x1_tensor)
    mse_bvp1 = nn.MSELoss()(bvp_y1_tensor, bvp_y1_pred)
    # bvp_x2_tensor = euro_call_data.normalize(bvp_x2_tensor)
    bvp_y2_pred = model(bvp_x2_tensor)
    mse_bvp2 = nn.MSELoss()(bvp_y2_tensor, bvp_y2_pred)

    # Aggregate the "data loss"
    loss1 = mse_ivp + BVP1_PENALTY*mse_bvp1 + mse_bvp2

    # Compute the "Black-Scholes loss"
    X1,y1 = euro_call_data.get_diff_data(N_sample)
    X1 = torch.from_numpy(X1).float().requires_grad_().to(DEVICE)
    y1 = torch.from_numpy(y1).float().to(DEVICE)
    y1_hat = model(X1)
    grads = torch.autograd.grad(y1_hat, X1, grad_outputs=torch.ones(y1_hat.shape).to(DEVICE), retain_graph=True, create_graph=True, only_inputs=True)[0]
    dVdt, dVdS = grads[:, 0].view(-1, 1), grads[:, 1].view(-1, 1)
    grads2nd = torch.autograd.grad(dVdS, X1, grad_outputs=torch.ones(dVdS.shape).to(DEVICE), create_graph=True, only_inputs=True)[0]
    d2VdS2 = grads2nd[:, 1].view(-1, 1)
    S1 = X1[:, 1].view(-1, 1)
    bs_pde = dVdt + (0.5 * ((sigma * S1) ** 2) * d2VdS2) + (r * S1 * dVdS) - (r * y1_hat)
    loss2 = physics_lr * nn.MSELoss()(bs_pde, torch.zeros_like(bs_pde))

    # Backpropagate joint loss
    loss = loss1 + loss2
    loss_history["total_loss"].append(loss.item())
    loss_history["loss_ivp_bvp"].append(loss1.item())
    loss_history["loss_BS"].append(loss2.item())
    loss_history["loss_ivp"].append(mse_ivp.item())
    loss_history["loss_bvp1"].append(mse_bvp1.item())
    loss_history["loss_bvp2"].append(mse_bvp2.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    #normalise the ratios
    if ERR_SAMPLING:
      r_ivp,r_bvp1,r_bvp2 = get_sample_rt(mse_ivp.item(),mse_bvp1.item(),mse_bvp2.item())
    # Plot the result as training progresses
    if (i + 1) % 500 == 0:
        logging.info(f"Epoch {i+1}, Loss: {loss.item():.4f}")
        if DEVICE.type !="cuda":
          print(f"Epoch {i+1}, Loss: {loss.item():.4f}")
    if (i+1) % 1000 == 0:
      plot_solution(model, euro_call_data, i+1, experiment_dir)
# Out:
# Epoch 500, Loss: 14516.6367
# Epoch 1000, Loss: 12401.4541
# Epoch 1500, Loss: 11222.2373
# Epoch 2000, Loss: 10365.1025
# Epoch 2500, Loss: 9758.9170
# Epoch 3000, Loss: 9182.6650
# Epoch 3500, Loss: 8563.0273
# Epoch 4000, Loss: 7702.7383
# Epoch 4500, Loss: 7126.7505
# Epoch 5000, Loss: 6628.6226
# Epoch 5500, Loss: 6145.9316
# Epoch 6000, Loss: 5729.7827
# Epoch 6500, Loss: 5342.6924
# Epoch 7000, Loss: 4953.9575
# Epoch 7500, Loss: 4599.3643
# Epoch 8000, Loss: 4269.1343
# Epoch 8500, Loss: 3918.2314
# Epoch 9000, Loss: 3639.5466
# Epoch 9500, Loss: 3339.9182
# Epoch 10000, Loss: 3062.2976
# Epoch 10500, Loss: 2797.0105
# Epoch 11000, Loss: 2563.3650
# Epoch 11500, Loss: 2322.2346
# Epoch 12000, Loss: 2111.3748
# Epoch 12500, Loss: 1911.7100
# Epoch 13000, Loss: 1724.4393
# Epoch 13500, Loss: 1540.5753
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ashish1610dhiman/data_projects/pinn_option_pricing/european_call/b_experiments.ipynb Cell 18 line 4
#      <a href='vscode-notebook-cell:/Users/ashish1610dhiman/data_projects/pinn_option_pricing/european_call/b_experiments.ipynb#X23sZmlsZQ%3D%3D?line=45'>46</a> loss_history["loss_bvp2"].append(mse_bvp2.item())
#      <a href='vscode-notebook-cell:/Users/ashish1610dhiman/data_projects/pinn_option_pricing/european_call/b_experiments.ipynb#X23sZmlsZQ%3D%3D?line=46'>47</a> optimizer.zero_grad()
# ---> <a href='vscode-notebook-cell:/Users/ashish1610dhiman/data_projects/pinn_option_pricing/european_call/b_experiments.ipynb#X23sZmlsZQ%3D%3D?line=47'>48</a> loss.backward()
#      <a href='vscode-notebook-cell:/Users/ashish1610dhiman/data_projects/pinn_option_pricing/european_call/b_experiments.ipynb#X23sZmlsZQ%3D%3D?line=48'>49</a> optimizer.step()
#      <a href='vscode-notebook-cell:/Users/ashish1610dhiman/data_projects/pinn_option_pricing/european_call/b_experiments.ipynb#X23sZmlsZQ%3D%3D?line=49'>50</a> #normalise the ratios
#
# File ~/opt/anaconda3/envs/pinn_option/lib/python3.10/site-packages/torch/_tensor.py:483, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     436 r"""Computes the gradient of current tensor wrt graph leaves.
#     437
#     438 The graph is differentiated using the chain rule. If the tensor is
#    (...)
#     480         used to compute the attr::tensors.
#     481 """
#     482 if has_torch_function_unary(self):
# --> 483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#     486         self,
#     487         gradient=gradient,
#     488         retain_graph=retain_graph,
#     489         create_graph=create_graph,
#     490         inputs=inputs,
#     491     )
#     492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/opt/anaconda3/envs/pinn_option/lib/python3.10/site-packages/torch/overrides.py:1560, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1556 if _is_torch_function_mode_enabled():
#    1557     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1558     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1559     with _pop_mode_temporarily() as mode:
# -> 1560         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1561     if result is not NotImplemented:
#    1562         return result
#
# File ~/opt/anaconda3/envs/pinn_option/lib/python3.10/site-packages/torch/utils/_device.py:77, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#      75 if func in _device_constructors() and kwargs.get('device') is None:
#      76     kwargs['device'] = self.device
# ---> 77 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/pinn_option/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/opt/anaconda3/envs/pinn_option/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %% [markdown]
# ### Training Curve

# %%
loss_df = pd.DataFrame.from_dict(loss_history)
ax = loss_df[["total_loss"]].plot(logy=True,alpha=0.8)
loss_df[["total_loss"]].rename(columns={"total_loss":"MA loss"}).rolling(10).mean().plot(logy=True,alpha=0.8, label="MA", ax = ax)
plt.title("Total Training loss")
plt.savefig(experiment_dir+"/total_loss.jpg")

# %%
tail_result = loss_df.rolling(50).mean().tail(1)
logging.info(f"Loss results")
logging.info(f"{tail_result}")
# Out:
# INFO:root:Loss results
# INFO:root:       total_loss  loss_ivp_bvp   loss_BS  loss_bvp1  loss_bvp2  loss_ivp
# 79999    0.283381       0.19233  0.091051   0.000489   0.027197  0.161222

# %%
loss_df.rolling(10).mean().plot(logy=True,alpha=0.8, subplots = True)
plt.sup_title("Training Curve for Moving Average of losses")
plt.savefig(experiment_dir+"/ivp_bs_loss.jpg")

# %% [markdown]
# ## Visualisation of Results

# %%
# %matplotlib inline

# %%
s = np.linspace(S_range[0], S_range[1], 100)
t = np.linspace(t_range[0], t_range[1], 100)
s_grid, t_grid = np.meshgrid(s, t)
s_flat = s_grid.flatten()
t_flat = t_grid.flatten()
# Create a 2D tensor from the flattened arrays
X_test = torch.tensor(np.column_stack((t_flat, s_flat)), dtype=torch.float)
# X_test_norm = euro_call_data.normalize(X_test)
y_analytical_test = euro_call_data.get_analytical_soln(X_test[:,1],X_test[:,0])
model.eval();
with torch.no_grad():
  y_pinn_test = model(X_test)
# Create the 3D plot
fig = plt.figure(figsize=(14,7))
ax = fig.add_subplot(121, projection='3d')
ax.plot_surface(s_grid, t_grid, y_analytical_test.cpu().numpy().reshape(s_grid.shape), cmap = "viridis")
ax.set_title("Analytical Soln")
ax.set_xlabel("Spot Price")
ax.set_ylabel(f"current time (t), $t \in {[t_range]}$")
ax.set_zlabel("Call price")
ax.view_init(elev=20, azim=-120)
ax = fig.add_subplot(122, projection='3d')
ax.plot_surface(s_grid, t_grid, y_pinn_test.cpu().numpy().reshape(s_grid.shape), cmap = "viridis")
ax.set_title("PINN prediction")
ax.set_xlabel("Spot Price")
ax.set_ylabel(f"current time (t), $t \in {[t_range]}$")
ax.set_zlabel("Call price")
ax.view_init(elev=20, azim=-120)
plt.savefig(experiment_dir+f"/true_vs_pred_final.jpg")

# %%
# %matplotlib inline

# %%
fig = plt.figure(figsize=(14,7))
ax = fig.add_subplot(121, projection='3d')
err = y_pinn_test.cpu().numpy().reshape(s_grid.shape) - y_analytical_test.cpu().numpy().reshape(s_grid.shape)
ax.plot_surface(s_grid, t_grid, err, cmap = "viridis")
ax.plot_surface(s_grid, t_grid, np.zeros(err.shape), color = "grey")
ax.set_title("Analytical Soln - Predicted")
ax.set_xlabel("Spot Price")
ax.set_ylabel("Time to expiry")
ax.set_zlabel("Call price")
ax.view_init(elev=20, azim=-120)
plt.show()

# %%
err = (y_pinn_test-y_analytical_test.reshape(y_analytical_test.shape[0],-1)).cpu().numpy()
loss_mse = np.square(err).sum()/(len(err))
print(f"MSE net: {loss_mse:.3f}")
logging.info(f"MSE net: {loss_mse:.3f}")
# Out:
# INFO:root:MSE net: 1.845
# MSE net: 1.845

# %% [markdown]
# ### Corealtion

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x= y_pinn_test.cpu().numpy(), y = y_analytical_test.cpu().numpy(), marker = "x", alpha = 0.5)
plt.plot([min(y_pinn_test.cpu().numpy().min(), y_analytical_test.cpu().numpy().min()),\
          max(y_pinn_test.cpu().numpy().max(), y_analytical_test.cpu().numpy().max())],
         [min(y_pinn_test.cpu().numpy().min(), y_analytical_test.cpu().numpy().min()),\
          max(y_pinn_test.cpu().numpy().max(), y_analytical_test.cpu().numpy().max())],
         linestyle='--', color='red', label='Diagonal line')
plt.xlabel("PINN prediction")
plt.ylabel("Analytical prediction")
plt.title("European Call Option pricing")
plt.savefig(experiment_dir+"/true_vs_pred_coef.jpg")
coef_res = np.corrcoef(y_pinn_test.cpu().numpy().reshape(y_pinn_test.shape[0],),y_analytical_test.cpu().numpy())
logging.info(f"Coef: {coef_res[0,1]:.3f}")
print(f"Coef: {coef_res[0,1]:.3f}")
# Out:
# INFO:root:Coef: 1.000
# Coef: 1.000

# %%
torch.save(model.state_dict(), f"{experiment_dir}/model_path")

# %%
plt.scatter(x= y_analytical_test.cpu().numpy(), y=err, marker = ".", alpha = 0.5)
plt.axhline(0,linestyle="--",color="r")
plt.xlabel("PINN prediction")
plt.ylabel("Error = $y_{true} - y_{pinn}$")
plt.title("European Call Option pricing")
plt.savefig(experiment_dir+"/true_vs_pred_error1.jpg")

# %%
# !zip -r ./{experiment_dir}.zip $experiment_dir
# Out:
#   adding: exp_gated3_correct_2d/ (stored 0%)
#   adding: exp_gated3_correct_2d/true_vs_pred_16000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_1000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_62000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_45000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_46000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_65000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_26000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_11000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_73000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/total_loss.jpg (deflated 32%)
#   adding: exp_gated3_correct_2d/true_vs_pred_34000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_21000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_53000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_58000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_23000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_18000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_36000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_13000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_31000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_72000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_29000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_76000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/model_path (deflated 9%)
#   adding: exp_gated3_correct_2d/true_vs_pred_40000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_6000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_32000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_41000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_5000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_15000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_38000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_9000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_56000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/ivp_bs_loss.jpg (deflated 25%)
#   adding: exp_gated3_correct_2d/true_vs_pred_68000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_52000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_4000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_63000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_69000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_error1.jpg (deflated 13%)
#   adding: exp_gated3_correct_2d/true_vs_pred_12000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_27000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_2000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_74000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_61000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_22000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_67000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_44000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_10000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_final.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_coef.jpg (deflated 29%)
#   adding: exp_gated3_correct_2d/true_vs_pred_55000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_70000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_54000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_51000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_33000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_75000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_64000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_28000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_48000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_60000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_3000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/exp_gated3_correct_2d_log_2023-12-01.log (deflated 78%)
#   adding: exp_gated3_correct_2d/true_vs_pred_8000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_71000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_66000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_30000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_57000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_77000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_78000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_79000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_59000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_14000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_17000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_19000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_7000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_80000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_24000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_25000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_43000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_35000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_39000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_50000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_49000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_42000.jpg (deflated 15%)
#   adding: exp_gated3_correct_2d/true_vs_pred_20000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_47000.jpg (deflated 14%)
#   adding: exp_gated3_correct_2d/true_vs_pred_37000.jpg (deflated 15%)
